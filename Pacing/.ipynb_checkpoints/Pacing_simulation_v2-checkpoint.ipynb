# %% [markdown]
# # 2ème version des simulations

# %% [markdown]
# Cas :
# - prix fixes
# - proba = 1
# - ajouts de pb techniques

# %%
import numpy as np
import random 
import simpy

# %% [markdown]
# L'objectif est de créer une dynamique aléatoire d'arrivée des bid requests qui suivent une certaine variable aléatoire. On ne connaît pas donc le nombre de BR sur une période donnée. ```Filtre de Kalman``` pour obtenir des estimations dynamiques.
#
# Le déroulement est le suivant :
# 1. Fixer les constantes globales : Budget, proba de gagner, prix de chaque impression, horaires de la journée
# 2. Générer les variables aléatoires pour les bids requests et les impressions associées
# 3. Simuler avec un simulateur à événement discret l'arrivée des bid requests + pacing/sec sans algo
# 4. Implémenter une estimation dynamique du nombre d'impressions (prix par impression)
# 5. Determiner une probabilité d'achat d'une br selon le nombre d'impressions estimée
# 6. Mesure de performances (ecart au budget, nb d'impressions gagnées etc.)

# %% [markdown]
# ### Etape 1 - Constantes globales

# %% [markdown]
# On va supposer que l'on connaît les horaires d'une journée (8h - 18h)
#
# On connaît le budget (1000 euros par heure)
#
# On connaît le prix (1 euro par impression)
#
# On gagne à chaque bid

# %%
nombre_heures = 10
B = 1800
P = 1

# %% [markdown]
# ### Etape 2 - Générer les variables aléatoires

# %% [markdown]
# 1) Variable aléatoire sur le délai entre chaque bid request
#
# 2) Variable aléatoire sur le nombre d'impressions par bid request ------- Note : au début les deux ne sont pas forcément liés mais à termes on pourra instaurer une dépendance (plus proche de la réalité)

# %%
def delai():
    secondes = np.random.poisson(2)
    if not random.random() < 0.98:
        secondes = np.random.poisson(600)
    return secondes

# %%
def imps():
    nb_imp = np.random.poisson(3)
    return nb_imp

# %%
def bid_proba(p):
    return random.random() < p

# %% [markdown]
# ### Etape 3 - Simulation

# %%
def open_rtb(env):
    B = 30
    duree_totale = 60
    cible = B/duree_totale
    while True:
        # Nombre d'impressions
        nb_imp = imps()
        print(f"bid request avec {nb_imp} impressions")
        number_imps_br.append(nb_imp)
        
        # Calcul du budget par seconde restant
        rt = duree_totale - env.now
        B_sec = B/rt
        b_sec.append(B_sec)
        print(f"\t Budget par sec de {B_sec} euros")
        
        # Proba d'acheter
        if B_sec >= cible:
            proba = 1
        else:
            proba = 0
        
        # Achat ou pas
        if bid_proba(proba):
            B -= 1
            print(f"\t Achat de {P} euros. Il reste {B} euros")
        else:
            print(f"\t Pas d'achat. Il reste {B} euros")
        B_remain.append(B)
        
        # Temps restant de la simulation
        print(f"\t Il reste {rt} secondes avant la fin de la simulation \n")
        
        # Temps avant la prochaine BR
        time = delai() 
        
        # Test pour faire des trucs a la fin de la simulation
        if rt < time:
            print("Fin de la simulation")
            print(f"Le budget restant est de {B} euros")
        yield env.timeout(time)

# %%
env = simpy.rt.RealtimeEnvironment(factor=1.0, strict=False)
proc = env.process(open_rtb(env))

# %%
number_imps_br = []
b_sec = []
B_remain = []
env.run(until=60)
# Out:
# bid request avec 3 impressions
# 	 Budget par sec de 0.5 euros
# 	 Achat de 1 euros. Il reste 29 euros
# 	 Il reste 60 secondes avant la fin de la simulation
#
# bid request avec 1 impressions
# 	 Budget par sec de 0.5 euros
# 	 Achat de 1 euros. Il reste 28 euros
# 	 Il reste 58 secondes avant la fin de la simulation
#
# bid request avec 4 impressions
# 	 Budget par sec de 0.49122807017543857 euros
# 	 Pas d'achat. Il reste 28 euros
# 	 Il reste 57 secondes avant la fin de la simulation
#
# bid request avec 7 impressions
# 	 Budget par sec de 0.509090909090909 euros
# 	 Achat de 1 euros. Il reste 27 euros
# 	 Il reste 55 secondes avant la fin de la simulation
#
# bid request avec 3 impressions
# 	 Budget par sec de 0.5094339622641509 euros
# 	 Achat de 1 euros. Il reste 26 euros
# 	 Il reste 53 secondes avant la fin de la simulation
#
# bid request avec 0 impressions
# 	 Budget par sec de 0.5306122448979592 euros
# 	 Achat de 1 euros. Il reste 25 euros
# 	 Il reste 49 secondes avant la fin de la simulation
#
# bid request avec 2 impressions
# 	 Budget par sec de 0.5319148936170213 euros
# 	 Achat de 1 euros. Il reste 24 euros
# 	 Il reste 47 secondes avant la fin de la simulation
#
# bid request avec 3 impressions
# 	 Budget par sec de 0.5454545454545454 euros
# 	 Achat de 1 euros. Il reste 23 euros
# 	 Il reste 44 secondes avant la fin de la simulation
#
# bid request avec 4 impressions
# 	 Budget par sec de 0.575 euros
# 	 Achat de 1 euros. Il reste 22 euros
# 	 Il reste 40 secondes avant la fin de la simulation
#
# bid request avec 0 impressions
# 	 Budget par sec de 0.5641025641025641 euros
# 	 Achat de 1 euros. Il reste 21 euros
# 	 Il reste 39 secondes avant la fin de la simulation
#
# bid request avec 5 impressions
# 	 Budget par sec de 0.5833333333333334 euros
# 	 Achat de 1 euros. Il reste 20 euros
# 	 Il reste 36 secondes avant la fin de la simulation
#
# bid request avec 1 impressions
# 	 Budget par sec de 0.5555555555555556 euros
# 	 Achat de 1 euros. Il reste 19 euros
# 	 Il reste 36 secondes avant la fin de la simulation
#
# bid request avec 7 impressions
# 	 Budget par sec de 0.5277777777777778 euros
# 	 Achat de 1 euros. Il reste 18 euros
# 	 Il reste 36 secondes avant la fin de la simulation
#
# bid request avec 4 impressions
# 	 Budget par sec de 0.5142857142857142 euros
# 	 Achat de 1 euros. Il reste 17 euros
# 	 Il reste 35 secondes avant la fin de la simulation
#
# bid request avec 2 impressions
# 	 Budget par sec de 0.5151515151515151 euros
# 	 Achat de 1 euros. Il reste 16 euros
# 	 Il reste 33 secondes avant la fin de la simulation
#
# bid request avec 4 impressions
# 	 Budget par sec de 0.5333333333333333 euros
# 	 Achat de 1 euros. Il reste 15 euros
# 	 Il reste 30 secondes avant la fin de la simulation
#
# bid request avec 1 impressions
# 	 Budget par sec de 0.5 euros
# 	 Achat de 1 euros. Il reste 14 euros
# 	 Il reste 30 secondes avant la fin de la simulation
#
# bid request avec 3 impressions
# 	 Budget par sec de 0.4827586206896552 euros
# 	 Pas d'achat. Il reste 14 euros
# 	 Il reste 29 secondes avant la fin de la simulation
#
# bid request avec 1 impressions
# 	 Budget par sec de 0.5 euros
# 	 Achat de 1 euros. Il reste 13 euros
# 	 Il reste 28 secondes avant la fin de la simulation
#
# bid request avec 3 impressions
# 	 Budget par sec de 0.4642857142857143 euros
# 	 Pas d'achat. Il reste 13 euros
# 	 Il reste 28 secondes avant la fin de la simulation
#
# bid request avec 5 impressions
# 	 Budget par sec de 0.5 euros
# 	 Achat de 1 euros. Il reste 12 euros
# 	 Il reste 26 secondes avant la fin de la simulation
#
# bid request avec 0 impressions
# 	 Budget par sec de 0.5 euros
# 	 Achat de 1 euros. Il reste 11 euros
# 	 Il reste 24 secondes avant la fin de la simulation
#
# bid request avec 2 impressions
# 	 Budget par sec de 0.5 euros
# 	 Achat de 1 euros. Il reste 10 euros
# 	 Il reste 22 secondes avant la fin de la simulation
#
# bid request avec 3 impressions
# 	 Budget par sec de 0.45454545454545453 euros
# 	 Pas d'achat. Il reste 10 euros
# 	 Il reste 22 secondes avant la fin de la simulation
#
# bid request avec 4 impressions
# 	 Budget par sec de 0.47619047619047616 euros
# 	 Pas d'achat. Il reste 10 euros
# 	 Il reste 21 secondes avant la fin de la simulation
#
# bid request avec 3 impressions
# 	 Budget par sec de 0.5555555555555556 euros
# 	 Achat de 1 euros. Il reste 9 euros
# 	 Il reste 18 secondes avant la fin de la simulation
#
# bid request avec 3 impressions
# 	 Budget par sec de 0.5294117647058824 euros
# 	 Achat de 1 euros. Il reste 8 euros
# 	 Il reste 17 secondes avant la fin de la simulation
#
# bid request avec 2 impressions
# 	 Budget par sec de 0.6153846153846154 euros
# 	 Achat de 1 euros. Il reste 7 euros
# 	 Il reste 13 secondes avant la fin de la simulation
#
# bid request avec 1 impressions
# 	 Budget par sec de 0.5833333333333334 euros
# 	 Achat de 1 euros. Il reste 6 euros
# 	 Il reste 12 secondes avant la fin de la simulation
#
# bid request avec 0 impressions
# 	 Budget par sec de 0.6 euros
# 	 Achat de 1 euros. Il reste 5 euros
# 	 Il reste 10 secondes avant la fin de la simulation
#
# bid request avec 1 impressions
# 	 Budget par sec de 0.625 euros
# 	 Achat de 1 euros. Il reste 4 euros
# 	 Il reste 8 secondes avant la fin de la simulation
#
# bid request avec 3 impressions
# 	 Budget par sec de 0.6666666666666666 euros
# 	 Achat de 1 euros. Il reste 3 euros
# 	 Il reste 6 secondes avant la fin de la simulation
#
# bid request avec 3 impressions
# 	 Budget par sec de 0.5 euros
# 	 Achat de 1 euros. Il reste 2 euros
# 	 Il reste 6 secondes avant la fin de la simulation
#
# bid request avec 0 impressions
# 	 Budget par sec de 2.0 euros
# 	 Achat de 1 euros. Il reste 1 euros
# 	 Il reste 1 secondes avant la fin de la simulation
#
# Fin de la simulation
# Le budget restant est de 1 euros

# %% [markdown]
# Essayons de changer quelques constantes pour voir ce qu'il se passe.
#
# Il faudrait aussi intégrer le fait que l'algo doit tourner sur toute une journée de 10h.

# %%
def open_rtb(env, B, duree_totale_heure, P):
    duree_totale = duree_totale_heure * 3600
    cible = B/duree_totale
    while True:
        # Nombre d'impressions
        nb_imp = imps()
        number_imps_br.append(nb_imp)
        
        # Calcul du budget par seconde restant
        rt = duree_totale - env.now
        B_sec = B/rt
        b_sec.append(B_sec)
        
        # Proba d'acheter
        if B_sec >= cible:
            proba = 1
        else:
            proba = 0
        
        # Achat ou pas
        if bid_proba(proba):
            B -= P
        B_remain.append(B)
        
        # Temps avant la prochaine BR
        time = delai()
        
        # Test pour faire des trucs a la fin de la simulation
        if rt < time:
            print("Fin de la simulation")
            print(f"Le budget restant est de {B} euros")
        yield env.timeout(time)

# %%
# Paramètres à changer
nombre_heures = 10
B = 1000
P = 5

# %%
env = simpy.Environment()
proc = env.process(open_rtb(env, B, nombre_heures, P))

# %%
number_imps_br = []
b_sec = []
B_remain = []
duree_totale_sec = nombre_heures * 3600
env.run(until=duree_totale_sec)
# Out:
# Fin de la simulation
# Le budget restant est de 10 euros

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.plot(B_remain, linewidth=3)
# Set chart title and label axes.
ax.set_title("Evolution du budget", fontsize=18)
ax.set_xlabel("Temps", fontsize=14)
ax.set_ylabel("Budget", fontsize=14)
# Set size of tick labels.
ax.tick_params(axis='both', labelsize=14)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.plot(b_sec, linewidth=.5)
# Set chart title and label axes.
ax.set_title("Evolution du budget par seconde", fontsize=18)
ax.set_xlabel("Temps", fontsize=14)
ax.set_ylabel("Budget par seconde", fontsize=14)
# Set size of tick labels.
ax.tick_params(axis='both', labelsize=14)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# Le problème actuel est qu'il y a toujours un pic de budget par seconde en fin de période et donc ce n'est pas forcément efficient. L'objectif serait d'annihiler cet effet pic à la fin.
#
# Mais tout d'abord nous devons essaer d'améliorer la simulation afin qu'elle colle plus à la réalité. Nous pouvons par exemple déterminer un prix fixe par impression et non pas par BR.

# %% [markdown]
# ### Etape 4 - Prix par impression

# %%
def open_rtb(env, B, duree_totale_heure, P):
    duree_totale = duree_totale_heure * 3600
    cible = B/duree_totale
    spending = 0
    while True:
        # Nombre d'impressions
        nb_imp = imps()
        Prix = P * nb_imp
        prix_liste.append(Prix)
        
        # Calcul du budget par seconde restant
        rt = duree_totale - env.now
        B_sec = B/rt
        b_sec.append(B_sec)
        
        # Proba d'acheter
        if B_sec >= cible:
            proba = 1
        else:
            proba = 0
        
        # Achat ou pas
        if bid_proba(proba):
            B -= Prix
            spending += Prix
        B_remain.append(B)
        
        # Budget par seconde effectivement dépensé
        try:
            spend_b.append(spending/env.now)
        except ZeroDivisionError:
            spend_b.append(0)
        
        # Temps avant la prochaine BR
        time = delai()
        
        # Test pour faire des trucs a la fin de la simulation
        if rt < time:
            print("Fin de la simulation")
            print(f"Le budget restant est de {B} euros")
        yield env.timeout(time)

# %%
# Paramètres à changer
nombre_heures = 10
B = 1000
P = 1

# %%
env = simpy.Environment()
proc = env.process(open_rtb(env, B, nombre_heures, P))

# %%
spend_b = []
b_sec = []
B_remain = []
prix_liste = []
duree_totale_sec = nombre_heures * 3600
env.run(until=duree_totale_sec)
# Out:
# Fin de la simulation
# Le budget restant est de 5 euros

# %%
plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.plot(B_remain, linewidth=3)
# Set chart title and label axes.
ax.set_title("Evolution du budget", fontsize=18)
ax.set_xlabel("Temps", fontsize=14)
ax.set_ylabel("Budget", fontsize=14)
# Set size of tick labels.
ax.tick_params(axis='both', labelsize=14)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.plot(spend_b, linewidth=.5)
# Set chart title and label axes.
ax.set_title("Evolution du budget par seconde effectivement dépensé", fontsize=18)
ax.set_xlabel("Temps", fontsize=14)
ax.set_ylabel("Budget par seconde", fontsize=14)
# Set size of tick labels.
ax.tick_params(axis='both', labelsize=14)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# On voit que le budget par seconde effectivement dépensé prend un certain temps avant de se stabiliser mais une fois que c'est le cas la dépense est très bien lissée sur toute la période.

# %%
plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.plot(prix_liste, linewidth=.5)
# Set chart title and label axes.
ax.set_title("Evolution du prix des BR", fontsize=18)
ax.set_xlabel("Temps", fontsize=14)
ax.set_ylabel("Prix", fontsize=14)
# Set size of tick labels.
ax.tick_params(axis='both', labelsize=14)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# Le budget a été dépensé totalement (ou presque selon les simulations) sur toute la journée donc le pacing semble bien fonctionner. Cependant il y a toujours le problème de pic de dépense en fin de journée.
