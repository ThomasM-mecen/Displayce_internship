# %% [markdown]
# # Check confidence interval

# %%
from datetime import datetime, timedelta
import pandas as pd
from statsmodels.formula.api import ols

# %%
def gen_prop_lr(br_object):
    aggr = br_object.imps.groupby([br_object.index.date, br_object.index.weekday, br_object.index.hour]).sum()
    aggr.index.names = ['date', 'weekday', 'hour']
    aggr = aggr.reset_index()
    model = ols('imps ~ C(weekday) + C(hour)', data=aggr).fit()
    weekday_list = range(7)
    weekday_list = list(itertools.chain.from_iterable(itertools.repeat(x, 24) for x in weekday_list))
    hour_list = list()
    for i in range(7):
        for z in range(24):
            hour_list.append(z)
    df_fitting = pd.DataFrame({'weekday': weekday_list, 'hour': hour_list})
    prediction = model.predict(df_fitting)
    df_fitting['fitted'] = prediction
    pattern = df_fitting.pivot_table('fitted', index=df_fitting.hour, columns=df_fitting.weekday)
    line, col = pattern.shape
    for i in range(col):
        pattern.iloc[:, i] = pattern.iloc[:, i] * 100 / pattern.iloc[:, i].sum()
    return pattern

# %%
def gen_prop_lr_hour(br_object):
    aggr = br_object.imps.groupby([br_object.index.date, br_object.index.hour]).sum().reset_index()
    aggr.columns = ['date', 'hour', 'imps']
    model = ols('imps ~ C(hour)', data=aggr).fit()
    hour_list = list()
    for z in range(24):
        hour_list.append(z)
    df_fitting = pd.DataFrame({'hour': hour_list})
    prediction = model.predict(df_fitting)
    df_fitting['fitted'] = prediction
    df_fitting.index = df_fitting.hour
    del df_fitting['hour']
    df_fitting.iloc[:, 0] = df_fitting.iloc[:, 0] * 100 / df_fitting.iloc[:, 0].sum()
    return df_fitting

# %%
records = []
for i in range(24 * 8):
    records.append(
        {'date': datetime(2020, 8, 4, 0, 59, 59) + timedelta(hours=i),
         'imps': 100}
    )
df = pd.DataFrame.from_records(records, index='date')

# %%
df = pd.read_pickle('br_clean.pkl')

# %%
data = df[df.TZ == 'America/New_York']
data.set_index('local_date', inplace=True)
data.sort_index(inplace = True)

# %%
aggr = data.imps.groupby([data.index.date, data.index.weekday, data.index.hour]).sum()
aggr.index.names = ['date', 'weekday', 'hour']
aggr = aggr.reset_index()
model = ols('imps ~ C(weekday) + C(hour)', data=aggr).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   imps   R-squared:                       0.189
# Model:                            OLS   Adj. R-squared:                  0.024
# Method:                 Least Squares   F-statistic:                     1.144
# Date:                Wed, 05 Aug 2020   Prob (F-statistic):              0.296
# Time:                        16:19:37   Log-Likelihood:                -1798.5
# No. Observations:                 172   AIC:                             3657.
# Df Residuals:                     142   BIC:                             3751.
# Df Model:                          29
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept        1.466e+05   3911.114     37.474      0.000    1.39e+05    1.54e+05
# C(weekday)[T.1] -5701.0237   2584.561     -2.206      0.029   -1.08e+04    -591.836
# C(weekday)[T.2] -3046.5890   2672.624     -1.140      0.256   -8329.862    2236.684
# C(weekday)[T.3] -3156.9941   2672.624     -1.181      0.239   -8440.268    2126.279
# C(weekday)[T.4] -3477.0291   2672.624     -1.301      0.195   -8760.302    1806.244
# C(weekday)[T.5]   524.2096   2672.624      0.196      0.845   -4759.064    5807.483
# C(weekday)[T.6]   -81.4320   2672.624     -0.030      0.976   -5364.705    5201.841
# C(hour)[T.1]     -165.9778   4948.739     -0.034      0.973   -9948.699    9616.744
# C(hour)[T.2]     -231.5152   4948.739     -0.047      0.963      -1e+04    9551.206
# C(hour)[T.3]      160.3929   4948.739      0.032      0.974   -9622.328    9943.114
# C(hour)[T.4]       33.0815   4948.739      0.007      0.995   -9749.640    9815.803
# C(hour)[T.5]      895.7605   4948.739      0.181      0.857   -8886.961    1.07e+04
# C(hour)[T.6]     2030.8110   4948.739      0.410      0.682   -7751.910    1.18e+04
# C(hour)[T.7]     1923.9505   4948.739      0.389      0.698   -7858.771    1.17e+04
# C(hour)[T.8]     3156.4368   4948.739      0.638      0.525   -6626.285    1.29e+04
# C(hour)[T.9]     2705.9556   4948.739      0.547      0.585   -7076.766    1.25e+04
# C(hour)[T.10]    2020.7346   4948.739      0.408      0.684   -7761.987    1.18e+04
# C(hour)[T.11]    1943.9082   4948.739      0.393      0.695   -7838.813    1.17e+04
# C(hour)[T.12]    1475.4730   4948.739      0.298      0.766   -8307.248    1.13e+04
# C(hour)[T.13]    1367.2733   4948.739      0.276      0.783   -8415.448    1.11e+04
# C(hour)[T.14]    1145.8987   4948.739      0.232      0.817   -8636.823    1.09e+04
# C(hour)[T.15]    2031.3756   4948.739      0.410      0.682   -7751.346    1.18e+04
# C(hour)[T.16]    1404.5590   4948.739      0.284      0.777   -8378.162    1.12e+04
# C(hour)[T.17]    1498.7266   4948.739      0.303      0.762   -8283.995    1.13e+04
# C(hour)[T.18]     915.3393   4948.739      0.185      0.854   -8867.382    1.07e+04
# C(hour)[T.19]    1396.0701   4948.739      0.282      0.778   -8386.651    1.12e+04
# C(hour)[T.20]    1082.0319   4796.030      0.226      0.822   -8398.814    1.06e+04
# C(hour)[T.21]    1108.9136   4796.030      0.231      0.817   -8371.932    1.06e+04
# C(hour)[T.22]     929.2840   4796.030      0.194      0.847   -8551.562    1.04e+04
# C(hour)[T.23]   -1.413e+04   4796.030     -2.946      0.004   -2.36e+04   -4648.554
# ==============================================================================
# Omnibus:                      328.880   Durbin-Watson:                   1.150
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           103141.979
# Skew:                          -9.849   Prob(JB):                         0.00
# Kurtosis:                     121.338   Cond. No.                         26.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
ic = model.conf_int(alpha=0.05)
ic.columns = ['inf', 'sup']

# %%
ic['size'] = round((ic['inf'] - ic['sup']).abs(),5)

# %%
ic
# Out:
#                            inf            sup         size
# Intercept        138835.143402  154298.209292  15463.06589
# C(weekday)[T.1]  -10810.211811    -591.835579  10218.37623
# C(weekday)[T.2]   -8329.862350    2236.684424  10566.54677
# C(weekday)[T.3]   -8440.267506    2126.279268  10566.54677
# C(weekday)[T.4]   -8760.302475    1806.244300  10566.54677
# C(weekday)[T.5]   -4759.063796    5807.482979  10566.54677
# C(weekday)[T.6]   -5364.705355    5201.841420  10566.54677
# C(hour)[T.1]      -9948.699227    9616.743551  19565.44278
# C(hour)[T.2]     -10014.236606    9551.206172  19565.44278
# C(hour)[T.3]      -9622.328447    9943.114331  19565.44278
# C(hour)[T.4]      -9749.639845    9815.802933  19565.44278
# C(hour)[T.5]      -8886.960939   10678.481840  19565.44278
# C(hour)[T.6]      -7751.910438   11813.532340  19565.44278
# C(hour)[T.7]      -7858.770845   11706.671933  19565.44278
# C(hour)[T.8]      -6626.284566   12939.158212  19565.44278
# C(hour)[T.9]      -7076.765757   12488.677021  19565.44278
# C(hour)[T.10]     -7761.986797   11803.455982  19565.44278
# C(hour)[T.11]     -7838.813207   11726.629571  19565.44278
# C(hour)[T.12]     -8307.248341   11258.194438  19565.44278
# C(hour)[T.13]     -8415.448050   11149.994729  19565.44278
# C(hour)[T.14]     -8636.822733   10928.620045  19565.44278
# C(hour)[T.15]     -7751.345777   11814.097001  19565.44278
# C(hour)[T.16]     -8378.162412   11187.280366  19565.44278
# C(hour)[T.17]     -8283.994833   11281.447946  19565.44278
# C(hour)[T.18]     -8867.382100   10698.060678  19565.44278
# C(hour)[T.19]     -8386.651284   11178.791494  19565.44278
# C(hour)[T.20]     -8398.813748   10562.877536  18961.69128
# C(hour)[T.21]     -8371.932017   10589.759267  18961.69128
# C(hour)[T.22]     -8551.561616   10410.129669  18961.69128
# C(hour)[T.23]    -23610.245450   -4648.554165  18961.69128

# %%
databis = data['2020-07-07 23:58:00':'2020-07-10 23:59:59']

# %%
aggr = databis.imps.groupby([databis.index.date, databis.index.weekday, databis.index.hour]).sum()
aggr.index.names = ['date', 'weekday', 'hour']
aggr = aggr.reset_index()
model2 = ols('imps ~ C(weekday) + C(hour)', data=aggr).fit()

# %%
ic2 = model2.conf_int(alpha=0.05)
ic2.columns = ['inf', 'sup']

# %%
ic2['size'] = round((ic2['inf'] - ic2['sup']).abs(),5)

# %%
ic2
# Out:
#                            inf            sup        size
# Intercept          1868.415383    4174.271634  2305.85625
# C(weekday)[T.2]  138517.738184  140601.531518  2083.79333
# C(weekday)[T.3]  138407.333028  140491.126361  2083.79333
# C(weekday)[T.4]  138087.298059  140171.091393  2083.79333
# C(hour)[T.1]      -1067.755366     390.596176  1458.35154
# C(hour)[T.2]       -803.515212     654.836330  1458.35154
# C(hour)[T.3]       -846.713699     611.637843  1458.35154
# C(hour)[T.4]      -1018.184669     440.166873  1458.35154
# C(hour)[T.5]        499.835455    1958.186997  1458.35154
# C(hour)[T.6]       1256.642608    2714.994150  1458.35154
# C(hour)[T.7]       1598.782252    3057.133794  1458.35154
# C(hour)[T.8]       2111.598841    3569.950383  1458.35154
# C(hour)[T.9]       1679.280834    3137.632376  1458.35154
# C(hour)[T.10]      1818.414266    3276.765808  1458.35154
# C(hour)[T.11]      1875.726840    3334.078382  1458.35154
# C(hour)[T.12]      1229.533418    2687.884960  1458.35154
# C(hour)[T.13]       959.585862    2417.937404  1458.35154
# C(hour)[T.14]      1314.839779    2773.191321  1458.35154
# C(hour)[T.15]      1431.639890    2889.991432  1458.35154
# C(hour)[T.16]      1420.688436    2879.039978  1458.35154
# C(hour)[T.17]      1324.261883    2782.613424  1458.35154
# C(hour)[T.18]       921.800419    2380.151961  1458.35154
# C(hour)[T.19]      1205.473904    2663.825446  1458.35154
# C(hour)[T.20]      1248.077306    2706.428848  1458.35154
# C(hour)[T.21]      1033.236577    2491.588119  1458.35154
# C(hour)[T.22]       614.331165    2072.682707  1458.35154
# C(hour)[T.23]       659.077004    2117.428546  1458.35154
